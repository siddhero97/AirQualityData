# %%
import requests

import numpy as np 
import pandas as pd

# %%
# https://www.kaggle.com/shrutibhargava94/india-air-quality-data

# %%
data  = pd.read_csv("files/data.csv",encoding="cp1252")
# Out:
# C:\Users\thoma\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data
# Out:
#        stn_code       sampling_date                        state   location  \
# 0           150  February - M021990               Andhra Pradesh  Hyderabad
# 1           151  February - M021990               Andhra Pradesh  Hyderabad
# 2           152  February - M021990               Andhra Pradesh  Hyderabad
# 3           150     March - M031990               Andhra Pradesh  Hyderabad
# 4           151     March - M031990               Andhra Pradesh  Hyderabad
# ...         ...                 ...                          ...        ...
# 435737     SAMP            24-12-15                  West Bengal   ULUBERIA
# 435738     SAMP            29-12-15                  West Bengal   ULUBERIA
# 435739      NaN                 NaN  andaman-and-nicobar-islands        NaN
# 435740      NaN                 NaN                  Lakshadweep        NaN
# 435741      NaN                 NaN                      Tripura        NaN
#
#                                            agency  \
# ...

# %%
up = data.query('state=="Uttar Pradesh"')
up
# Out:
#        stn_code sampling_date          state   location  \
# 368214        1      1/5/1987  Uttar Pradesh       Agra
# 368215        7      1/2/1987  Uttar Pradesh     Anpara
# 368216        2      1/9/1987  Uttar Pradesh       Agra
# 368217        3      1/1/1987  Uttar Pradesh       Agra
# 368218        4      1/2/1987  Uttar Pradesh       Agra
# ...         ...           ...            ...        ...
# 411025      807      17-12-15  Uttar Pradesh  Allahabad
# 411026      807      22-12-15  Uttar Pradesh  Allahabad
# 411027      807      24-12-15  Uttar Pradesh  Allahabad
# 411028      807      29-12-15  Uttar Pradesh  Allahabad
# 411029      807      31-12-15  Uttar Pradesh  Allahabad
#
#                                              agency  \
# 368214              Central Pollution Control Board
# 368215       Uttar Pradesh  Pollution Control Board
# 368216        Uttar Pradesh Pollution Control Board
# 368217        Uttar Pradesh Pollution Control Board
# ...

# %%
up.describe()
# Out:
#                 so2           no2          rspm           spm  pm2_5
# count  40289.000000  41346.000000  38507.000000  22042.000000    0.0
# mean      12.528500     27.610095    176.952308    372.663688    NaN
# std        9.593518     13.775910     83.426854    156.399342    NaN
# min        1.000000      2.000000      9.000000      0.000000    NaN
# 25%        7.000000     19.250000    128.000000    270.000000    NaN
# 50%        9.200000     27.300000    170.000000    377.000000    NaN
# 75%       17.000000     34.000000    216.000000    467.000000    NaN
# max      183.000000    592.000000   6307.033333   1235.000000    NaN

# %%
up["date"][368214][:7]
# Out:
# '1987-05'

# %%
up["year-month"] =up["date"].apply(lambda x: x[:7])
# Out:
# C:\Users\thoma\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
up
# Out:
#        stn_code sampling_date          state   location  \
# 368214        1      1/5/1987  Uttar Pradesh       Agra
# 368215        7      1/2/1987  Uttar Pradesh     Anpara
# 368216        2      1/9/1987  Uttar Pradesh       Agra
# 368217        3      1/1/1987  Uttar Pradesh       Agra
# 368218        4      1/2/1987  Uttar Pradesh       Agra
# ...         ...           ...            ...        ...
# 411025      807      17-12-15  Uttar Pradesh  Allahabad
# 411026      807      22-12-15  Uttar Pradesh  Allahabad
# 411027      807      24-12-15  Uttar Pradesh  Allahabad
# 411028      807      29-12-15  Uttar Pradesh  Allahabad
# 411029      807      31-12-15  Uttar Pradesh  Allahabad
#
#                                              agency  \
# 368214              Central Pollution Control Board
# 368215       Uttar Pradesh  Pollution Control Board
# 368216        Uttar Pradesh Pollution Control Board
# 368217        Uttar Pradesh Pollution Control Board
# ...

# %%
data = up.groupby(['stn_code','year-month','location']).mean()

# %%
data
# Out:
#                                     so2        no2        rspm         spm  \
# stn_code year-month location
# 1.0      1987-01    Agra       9.657143  15.642857         NaN  303.571429
#          1987-02    Agra      15.375000  22.175000         NaN  277.250000
#          1987-05    Agra      10.900000  30.700000         NaN  152.000000
#          1988-01    Agra      13.860000  17.720000         NaN  297.600000
#          1988-02    Agra       6.400000  10.950000         NaN  488.500000
# ...                                 ...        ...         ...         ...
# 98       2015-08    Kanpur     6.833333  38.333333  195.500000         NaN
#          2015-09    Kanpur     7.500000  41.833333  207.833333         NaN
#          2015-10    Kanpur     7.000000  43.666667  204.500000         NaN
#          2015-11    Kanpur     6.400000  40.400000  201.800000         NaN
#          2015-12    Kanpur     6.875000  44.125000  201.125000         NaN
#
#                               pm2_5
# ...

# %%
data
# Out:
#                            so2        no2        rspm         spm  pm2_5
# stn_code year-month
# 1.0      1987-01      9.657143  15.642857         NaN  303.571429    NaN
#          1987-02     15.375000  22.175000         NaN  277.250000    NaN
#          1987-05     10.900000  30.700000         NaN  152.000000    NaN
#          1988-01     13.860000  17.720000         NaN  297.600000    NaN
#          1988-02      6.400000  10.950000         NaN  488.500000    NaN
# ...                        ...        ...         ...         ...    ...
# 98       2015-08      6.833333  38.333333  195.500000         NaN    NaN
#          2015-09      7.500000  41.833333  207.833333         NaN    NaN
#          2015-10      7.000000  43.666667  204.500000         NaN    NaN
#          2015-11      6.400000  40.400000  201.800000         NaN    NaN
#          2015-12      6.875000  44.125000  201.125000         NaN    NaN
#
# [5890 rows x 5 columns]

# %%
data.to_csv("data/kaggleData.csv")

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-80-b66091c05874> in <module>
# ----> 1 data.get_group(1)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'get_group'
